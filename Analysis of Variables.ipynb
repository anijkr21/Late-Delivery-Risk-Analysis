# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %%
df = pd.read_csv('D:/DSE/Capstone Project/DataCo/DataCoSupplyChainDataset.csv', encoding='latin')

# %%
df.head()
# Out:
#        Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0     DEBIT                         3                              4
# 1  TRANSFER                         5                              4
# 2      CASH                         4                              4
# 3     DEBIT                         3                              4
# 4   PAYMENT                         2                              4
#
#    Benefit per order  Sales per customer   Delivery Status  \
# 0          91.250000          314.640015  Advance shipping
# 1        -249.089996          311.359985     Late delivery
# 2        -247.779999          309.720001  Shipping on time
# 3          22.860001          304.809998  Advance shipping
# 4         134.210007          298.250000  Advance shipping
#
#    Late_delivery_risk  Category Id   Category Name Customer City  \
# 0                   0           73  Sporting Goods        Caguas
# ...

# %%
Total = df.isnull().sum().sort_values(ascending=False)
Percent = (df.isnull().sum()*100/df.isnull().count()).sort_values(ascending=False)   

missing_data = pd.concat([Total, Percent], axis = 1, keys = ['Total', 'Percentage of Missing Values'])    
missing_data
# Out:
#                                 Total  Percentage of Missing Values
# Product Description            180519                    100.000000
# Order Zipcode                  155679                     86.239676
# Customer Lname                      8                      0.004432
# Customer Zipcode                    3                      0.001662
# Type                                0                      0.000000
# Order Profit Per Order              0                      0.000000
# Order Item Cardprod Id              0                      0.000000
# Order Item Discount                 0                      0.000000
# Order Item Discount Rate            0                      0.000000
# Order Item Id                       0                      0.000000
# Order Item Product Price            0                      0.000000
# Order Item Profit Ratio             0                      0.000000
# Order Item Quantity                 0                      0.000000
# ...

# %%
df_1 = df[['Days for shipment (scheduled)', 'Days for shipping (real)', 'Late_delivery_risk']]

# %%
df_1['Diff'] = df['Days for shipment (scheduled)'] - df['Days for shipping (real)']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 df_1['Diff'] = df['Days for shipment (scheduled)'] - df['Days for shipping (real)']
#
# NameError: name 'df_1' is not defined

# %%
df_1.head()
# Out:
#    Days for shipment (scheduled)  Days for shipping (real)  \
# 0                              4                         3
# 1                              4                         5
# 2                              4                         4
# 3                              4                         3
# 4                              4                         2
#
#    Late_delivery_risk  Diff
# 0                   0     1
# 1                   1    -1
# 2                   0     0
# 3                   0     1
# 4                   0     2

# %%
sns.heatmap(df_1.corr(), annot=True)
plt.show()

# %%
d = {}

for i in df.columns:
    a = df[i].nunique()
    d.update({i:a})

# %%
d
# Out:
# {'Type': 4,
#  'Days for shipping (real)': 7,
#  'Days for shipment (scheduled)': 4,
#  'Benefit per order': 21998,
#  'Sales per customer': 2927,
#  'Delivery Status': 4,
#  'Late_delivery_risk': 2,
#  'Category Id': 51,
#  'Category Name': 50,
#  'Customer City': 563,
#  'Customer Country': 2,
#  'Customer Email': 1,
#  'Customer Fname': 782,
#  'Customer Id': 20652,
#  'Customer Lname': 1109,
#  'Customer Password': 1,
#  'Customer Segment': 3,
#  'Customer State': 46,
#  'Customer Street': 7458,
#  'Customer Zipcode': 995,
#  'Department Id': 11,
#  'Department Name': 11,
#  'Latitude': 11250,
#  'Longitude': 4487,
#  'Market': 5,
#  'Order City': 3597,
#  'Order Country': 164,
#  'Order Customer Id': 20652,
#  'order date (DateOrders)': 65752,
#  'Order Id': 65752,
#  'Order Item Cardprod Id': 118,
#  'Order Item Discount': 1017,
#  'Order Item Discount Rate': 18,
#  'Order Item Id': 180519,
#  'Order Item Product Price': 75,
#  'Order Item Profit Ratio': 162,
# ...

# %%
df['Type'].unique()
# Out:
# array(['DEBIT', 'TRANSFER', 'CASH', 'PAYMENT'], dtype=object)

# %%
df['Days for shipment (scheduled)'].unique()
# Out:
# array([4, 1, 2, 0], dtype=int64)

# %%
df['Days for shipping (real)'].unique()
# Out:
# array([3, 5, 4, 2, 6, 0, 1], dtype=int64)

# %%
df['Delivery Status'].unique()
# Out:
# array(['Advance shipping', 'Late delivery', 'Shipping on time',
#        'Shipping canceled'], dtype=object)

# %%
df_cat = df.select_dtypes(include='object')

# %%
df_late = df[df['Late_delivery_risk']==1]

# %%
sns.countplot(data=df_late, x='Type')
plt.show()

# %%
sns.countplot(data=df_late, x='Customer Country')
plt.show()

# %%
plt.figure(figsize=(20,12))
sns.countplot(data=df_late, x='Customer State')
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.countplot(data=df_late, x='Order Country')
plt.xticks(rotation=90)
plt.show()

# %%
df_late['Order Country'].value_counts()
# Out:
# Estados Unidos                     13670
# Francia                             7341
# México                              7246
# Alemania                            5383
# Australia                           4613
# Brasil                              4331
# Reino Unido                         3903
# China                               3123
# India                               2684
# Italia                              2672
# Indonesia                           2328
# España                              2154
# El Salvador                         2091
# República Dominicana                2020
# Honduras                            1919
# Turquía                             1894
# Cuba                                1798
# Nicaragua                           1716
# Guatemala                           1529
# Nigeria                             1225
# Filipinas                           1162
# Países Bajos                        1053
# Argentina                            999
# ...

# %%
df['Customer Country'].nunique()
# Out:
# 2

# %%
df[df['Benefit per order']<0]['Order Country'].value_counts()
# Out:
# Estados Unidos                     4649
# Francia                            2391
# México                             2341
# Alemania                           1928
# Australia                          1613
# Brasil                             1465
# Reino Unido                        1347
# China                              1071
# India                               921
# Italia                              912
# Indonesia                           781
# El Salvador                         724
# España                              711
# Cuba                                692
# República Dominicana                689
# Honduras                            680
# Turquía                             627
# Nicaragua                           570
# Guatemala                           548
# Nigeria                             434
# Filipinas                           421
# Panamá                              390
# Países Bajos                        365
# ...

# %%
df_late['Customer Id'].value_counts()
# Out:
# 5654     39
# 3708     34
# 3979     34
# 3838     33
# 4663     32
# 9883     31
# 5648     31
# 10111    30
# 341      30
# 1512     30
# 2723     30
# 9740     30
# 11426    30
# 5691     29
# 664      29
# 123      29
# 6375     29
# 1657     28
# 2851     28
# 5173     28
# 1443     28
# 10591    28
# 5477     28
# 1492     28
# 3099     28
# 5097     28
# 9153     27
# 450      27
# 4022     27
# 10235    27
# 9371     27
# 9053     27
# 4200     27
# 5321     27
# 3957     27
# 11513    27
# 3889     27
# 12039    27
# 11645    27
# 10610    26
# 6474     26
# 6428     26
# 2467     26
# 10490    26
# 9432     26
# 12235    26
# 4539     26
# 12189    26
# 1824     26
# 791      26
# 7974     26
# 12431    26
# 5715     26
# 10699    26
# 847      26
# 4588     25
# 230      25
# 10612    25
# 4435     25
# 1688     25
# 7910     25
# 4454     25
# 9821     25
# 10707    25
# 7190     25
# 2027     25
# 1588     25
# 11048    25
# 6730     25
# 1762     25
# 6643     25
# ...

# %%
df[df['Customer Id']==5654]
# Out:
#             Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 6224     PAYMENT                         6                              4
# 6754     PAYMENT                         5                              4
# 6912     PAYMENT                         5                              4
# 10652    PAYMENT                         6                              4
# 10667    PAYMENT                         6                              4
# 10795   TRANSFER                         2                              1
# 11075   TRANSFER                         2                              1
# 11497   TRANSFER                         5                              2
# 11624   TRANSFER                         5                              2
# 11736   TRANSFER                         5                              2
# 30223   TRANSFER                         6                              4
# 30236   TRANSFER                         6                              4
# ...

# %%
df_late['Product Name'].value_counts()
# Out:
# Perfect Fitness Perfect Rip Deck                 13473
# Nike Men's CJ Elite 2 TD Football Cleat          12121
# Nike Men's Dri-FIT Victory Golf Polo             11476
# O'Brien Men's Neoprene Life Vest                 10565
# Field & Stream Sportsman 16 Gun Fire Safe         9516
# Pelican Sunstream 100 Kayak                       8492
# Diamondback Women's Serene Classic Comfort Bi     7487
# Nike Men's Free 5.0+ Running Shoe                 6629
# Under Armour Girls' Toddler Spine Surge Runni     5865
# Fighting video games                               455
# Summer dresses                                     367
# Children's heaters                                 348
# Web Camera                                         344
# Toys                                               291
# Adult dog supplies                                 290
# Porcelain crafts                                   271
# Lawn mower                                         270
# ...

# %%
df_late['Shipping Mode'].value_counts()
# Out:
# Standard Class    41023
# Second Class      26987
# First Class       26513
# Same Day           4454
# Name: Shipping Mode, dtype: int64

# %%
sns.countplot(data=df_late, x='Shipping Mode')
plt.show()

# %%
df_late['Product Category Id'].value_counts()
# Out:
# 17    13496
# 18    12121
# 24    11476
# 46    10565
# 45     9516
# 48     8517
# 43     7487
# 9      6805
# 29     6058
# 37     1143
# 40     1014
# 36      805
# 26      664
# 13      627
# 35      602
# 41      542
# 75      455
# 76      367
# 3       349
# 63      348
# 62      344
# 7       329
# 33      291
# 74      291
# 72      290
# 66      271
# 68      270
# 67      259
# 71      248
# 44      247
# 12      238
# 65      238
# 59      229
# 32      229
# 64      224
# 5       206
# 38      205
# 69      202
# 73      198
# 6       183
# 11      176
# 61      141
# 30      135
# 70      113
# 60      109
# 31       97
# 2        75
# 10       64
# 34       42
# 16       39
# 4        37
# Name: Product Category Id, dtype: int64

# %%
sns.scatterplot(data=df, y='Days for shipping (real)', x='Days for shipment (scheduled)', hue='Late_delivery_risk')
plt.show()

# %%
for i in df.select_dtypes(include=np.number).columns:
    sns.boxplot(data=df, x=i)
    plt.show()

# %%
df_1 = pd.DataFrame((df_late['Product Category Id'].value_counts()))
# Out:
#     Product Category Id
# 17                13496
# 18                12121
# 24                11476
# 46                10565
# 45                 9516

# %%
sns.lineplot(data=df_1, x=df_1.index, y='Product Category Id')
plt.show()

# %%
df_late['Product Name'].value_counts().head(10)
# Out:
# Perfect Fitness Perfect Rip Deck                 13473
# Nike Men's CJ Elite 2 TD Football Cleat          12121
# Nike Men's Dri-FIT Victory Golf Polo             11476
# O'Brien Men's Neoprene Life Vest                 10565
# Field & Stream Sportsman 16 Gun Fire Safe         9516
# Pelican Sunstream 100 Kayak                       8492
# Diamondback Women's Serene Classic Comfort Bi     7487
# Nike Men's Free 5.0+ Running Shoe                 6629
# Under Armour Girls' Toddler Spine Surge Runni     5865
# Fighting video games                               455
# Name: Product Name, dtype: int64

# %%
df_late['Order Country'].value_counts().head(10)
# Out:
# Estados Unidos    13670
# Francia            7341
# México             7246
# Alemania           5383
# Australia          4613
# Brasil             4331
# Reino Unido        3903
# China              3123
# India              2684
# Italia             2672
# Name: Order Country, dtype: int64

# %%
df_late['Order City'].value_counts().head(10)
# Out:
# New York City    1261
# Santo Domingo    1217
# Los Angeles       965
# Tegucigalpa       942
# Managua           925
# Mexico City       803
# Manila            766
# San Francisco     706
# London            672
# San Salvador      668
# Name: Order City, dtype: int64

# %%
df_late['Order Region'].value_counts().head(10)
# Out:
# Central America    15518
# Western Europe     15140
# South America       8111
# Oceania             5482
# Southeast Asia      5297
# Northern Europe     5292
# Southern Europe     5129
# Caribbean           4415
# South Asia          4350
# West of USA         4313
# Name: Order Region, dtype: int64

# %%
df_late['Market'].value_counts()
# Out:
# LATAM           28044
# Europe          27743
# Pacific Asia    22712
# USCA            14138
# Africa           6340
# Name: Market, dtype: int64

# %%
df_late['Order Status'].value_counts()
# Out:
# COMPLETE           34199
# PENDING_PAYMENT    22922
# PROCESSING         12503
# PENDING            11712
# CLOSED             11109
# ON_HOLD             5450
# PAYMENT_REVIEW      1082
# Name: Order Status, dtype: int64

# %%
df.drop(['Product Image', 'Product Description', 'Product Status', 'Customer Fname', 'Customer Lname', 
         'Customer Password', 'Customer Email'], axis=1, inplace=True)

# %%
df.shape
# Out:
# (180519, 46)

# %%
df_late['Customer Segment'].value_counts()
# Out:
# Consumer       51248
# Corporate      29982
# Home Office    17747
# Name: Customer Segment, dtype: int64

# %%
df_late.shape
# Out:
# (98977, 53)

# %%
sns.countplot(df['Days for shipment (scheduled)'])
plt.show()
# Out:
# C:\Users\MAHE\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(df['Days for shipping (real)'])
plt.show()
# Out:
# C:\Users\MAHE\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(df['Days for shipping (real)'] - df['Days for shipment (scheduled)'])
plt.show()
# Out:
# C:\Users\MAHE\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
